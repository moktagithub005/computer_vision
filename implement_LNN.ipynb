# %%
import tensorflow as tf
IMG_HEIGHT=224
IMG_WIDTH=224
IMG_CHANNELS=3
CLASS_NAMES=["daisy","dendelions","roses","sunflowers","tulip"]

# %%
## path to the dataset
DATA_DIR=r"C:\Users\ajaym\Downloads\flower_photos\flower_photos"
train_dataset=tf.keras.utils.image_dataset_from_directory(
    DATA_DIR,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size= (IMG_HEIGHT,IMG_WIDTH),
    batch_size=16
)

val_dataset=tf.keras.utils.image_dataset_from_directory(
    DATA_DIR,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size= (IMG_HEIGHT,IMG_WIDTH),
    batch_size=16

)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.

# %%
class_names=train_dataset.class_names
print("flower classes:",class_names)
# Out:
# flower classes: ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %%
import matplotlib.pyplot as plt
for images,labels in train_dataset.take(1):
    #show 3 images
    for i in range(3):
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title("label"+ class_names[labels[i]])

        plt.axis("off")
        plt.show()
